# %%
import pandas as pd
import numpy as np
from numpy import *
import seaborn as sb
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  
plt.rcParams['figure.dpi'] = 110
import scipy.stats as scp
from matplotlib import pyplot

# %%
df = pd.read_csv('data_diff.csv', encoding = "utf8")
diff= df['diff']

# %%
df[df['diff'] < -20]
# Out:
#      Unnamed: 0    X season_x  height  weight    TF              TT  price ws  \
# 677         678  687    18/19     176      77  Roma  Internazionale   24.0  s
#
#            role   ...    d18  liq div dA  dB  dC  price_tm    MV  diff  \
# 677  Midfielder   ...      0  181   a  1   0   0      38.0  45.0 -21.0
#
#      diff_tm
# 677     -7.0
#
# [1 rows x 144 columns]

# %%
df[df['diff'] > 20].TT.unique()
# Out:
# array(['Tottenham Hotspur', 'Arsenal', 'Manchester United',
#        'Manchester City', 'Chelsea', 'Liverpool', 'Napoli', 'Juventus',
#        'PSG', 'Everton', 'Barcelona', 'Internazionale', 'Bournemouth'],
#       dtype=object)

# %%
sb.set_style("whitegrid")
sb.distplot(diff, kde=True,bins=35, rug=True,color='#30678D')
plt.xlabel('Difference between MV and TF')
sb.despine(left=True)
# Out:
# C:\Users\letym\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sb.set_style("whitegrid")
sb.boxenplot(diff, color='#30678D')
plt.xlabel('Difference between MV and TF')
sb.despine(left=True)

# %%
sb.set_style("whitegrid")
fig = sb.boxenplot(x = 'countryB', y = 'diff', palette='viridis',  data = df)
fig.set(xlabel='Buyer Country', ylabel='Difference between fee paid and market value')
sb.despine(left=True)

# %%
df1 = pd.DataFrame(df[df['diff']< 20])

# %%
sb.set_style("whitegrid")
fig = sb.boxenplot(x = 'countryB', y = 'diff', palette='viridis',  data = df1)
fig.set(xlabel='Buyer Country', ylabel='Difference between fee paid and market value')
sb.despine(left=True)

# %%
ax = sb.catplot(x="countryB", y="diff", data=df,order= ['GB','FR','IT','ES','DE','BE','PT','NL','RU','TR','GR'],
                height=6, kind="bar", palette="viridis")
ax.set(xlabel='Buyer country', ylabel='Difference between fee earned and market value')
ax.despine(left=True)
# valori di mercato aggiornati prima della vendita quindi sono tutti più o meno calcolati con lo stesso algoritmo di TM
# Out:
# C:\Users\letym\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
h = sb.catplot(x="countryS", y="diff", data=df,order= ['GB','FR','IT','ES','DE','BE','PT','NL'],
                height=6, kind="bar", palette="viridis")
h.despine(left=True)
# Out:
# C:\Users\letym\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# buyer team how much is the difference between the MV and TF paid
#sb.set_style("whitegrid")
i = sb.catplot(x="TT", y="diff", data=df,height=10, kind="bar", palette="viridis",aspect=20/10,order = ['Chelsea','Manchester City', 'Manchester United','Liverpool', 'Sunderland', 'Tottenham Hotspur', 'Leicester City',
       'Southampton', 'West Ham United', 'Arsenal', 
       'Crystal Palace', 'Middlesbrough', 'Burnley', 'Bournemouth',
       'Everton', 'Swansea City','Huddersfield Town', 
        'Stoke City',  'Hull City','Brighton Hove Albion','Watford',
       'West Bromwich Albion', 'Newcastle United', 'Fulham', 'Wolverhampton', 'Cardiff',
 
 
'PSG', 'Rennes', 'Bordeaux', 'Lille','Olympique Marseille',
    'Monaco', 'Nantes', 'Olympique Lyonnais', 'Nice', 
       'Toulouse', 'Angers', 'Reims','Saint-Etienne',
 
       'Internazionale', 'Napoli','Roma', 'Juventus','Milan',
       'Atalanta',  'Sassuolo', 'Genoa', 'Lazio', 'Torino', 'Sampdoria',
       'Cagliari', 'Chievo', 'Udinese', 'Pescara', 'Bologna', 'Crotone', 'Frosinone', 
    'SPAL', 'Fiorentina', 'Empoli','Hellas Verona','Benevento', 
 
 
 'Atletico Madrid','Barcelona', 'Real Madrid', 'Eibar','Celta de Vigo', 'Levante','Rayo Vallecano', 'Real Valladolid',
       'Villarreal', 'Deportivo Alaves', 'Granada','Getafe',
       'Espanyol', 'Osasuna', 'Leganes', 'Sevilla',  'Athletic Club',
       'Girona', 'Las Palmas', 
       'Real Betis', 'Valencia', 'Malaga', 'Real Sociedad','SD Huesca','Deportivo La Coruna',
 
 'Werder Bremen', 'Hoffenheim','Stuttgart','Hannover 96',
       'Borussia Mgladbach', 'Borussia Dortmund', 'Wolfsburg',
       'Hamburger SV', 'Hertha BSC', 'Bayer Leverkusen', 'Freiburg',
       'Bayern Munchen', 'Mainz 05', 'FC Ingolstadt', 'Schalke 04',
       'Koln', 'Augsburg', 'RB Leipzig', 'Eintracht Frankfurt', 
 
 #portog
'Benfica', 'Sporting CP','Porto',

 #olanda  
 'Ajax','PSV',
 
 'Rubin Kazan', 'Zenit',
 
 'Fenerbahce','Galatasaray','Trabzonspor','Besiktas','Antalyaspor', 
       
 'Olympiacos'])
#i.despine(left=True)
i.set_xticklabels(rotation=90)
# Out:
# C:\Users\letym\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
i = sb.catplot(x="TF", y="diff", data=df,height=10, kind="bar", palette="viridis",aspect=20/10,order = ['Chelsea','Manchester City', 'Manchester United','Liverpool', 'Sunderland', 'Tottenham Hotspur', 'Leicester City',
       'Southampton', 'West Ham United', 'Arsenal', 
       'Crystal Palace', 'Middlesbrough', 'Burnley', 'Bournemouth',
       'Everton', 'Swansea City','Huddersfield Town', 
        'Stoke City',  'Hull City','Brighton Hove Albion','Watford',
       'West Bromwich Albion', 'Newcastle United', 'Fulham', 'Wolverhampton', 'Cardiff',
 
 
'PSG', 'Rennes', 'Bordeaux', 'Lille','Olympique Marseille',
    'Monaco', 'Nantes', 'Olympique Lyonnais', 'Nice', 
       'Toulouse', 'Angers', 'Reims','Saint-Etienne',
 
       'Internazionale', 'Napoli','Roma', 'Juventus','Milan',
       'Atalanta',  'Sassuolo', 'Genoa', 'Lazio', 'Torino', 'Sampdoria',
       'Cagliari', 'Chievo', 'Udinese', 'Pescara', 'Bologna', 'Crotone', 'Frosinone', 
    'SPAL', 'Fiorentina', 'Empoli','Hellas Verona','Benevento', 
 
 
 'Atletico Madrid','Barcelona', 'Real Madrid', 'Eibar','Celta de Vigo', 'Levante','Rayo Vallecano', 'Real Valladolid',
       'Villarreal', 'Deportivo Alaves', 'Granada','Getafe',
       'Espanyol', 'Osasuna', 'Leganes', 'Sevilla',  'Athletic Club',
       'Girona', 'Las Palmas', 
       'Real Betis', 'Valencia', 'Malaga', 'Real Sociedad','SD Huesca','Deportivo La Coruna',
 
 'Werder Bremen', 'Hoffenheim','Stuttgart','Hannover 96',
       'Borussia Mgladbach', 'Borussia Dortmund', 'Wolfsburg',
       'Hamburger SV', 'Hertha BSC', 'Bayer Leverkusen', 'Freiburg',
       'Bayern Munchen', 'Mainz 05', 'FC Ingolstadt', 'Schalke 04',
       'Koln', 'Augsburg', 'RB Leipzig', 'Eintracht Frankfurt', 
 
 #portog
'Benfica', 'Sporting CP','Porto',

 #olanda  
 'Ajax','PSV'])
#i.despine(left=True)
i.set_xticklabels(rotation=90)
# Out:
# C:\Users\letym\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
p1 = pd.read_csv('perc1.csv', encoding = "utf8")
p2 = pd.read_csv('perc2.csv', encoding = "utf8")

# %%
values = p1.perc
clrs = ['#B2DD2C' if ((x < 0.2) & (x>-0.4)) else '#472777' for x in values]

fig = sb.barplot(x = 'countryS', y='perc',data=p1, palette=clrs,order= ['GB','FR','IT','ES','DE','BE','PT','NL'])
sb.despine(left=True)
fig.set(xlabel='Percentage sales price compared to Germany', ylabel='Seller country')
# Out:
# [Text(0,0.5,'Seller country'),
#  Text(0.5,0,'Percentage sales price compared to Germany')]

# %%
values2 = p2.perc
clrs2 = ['#472777' if ((x < 0.98) & (x>0.3)) else '#B2DD2C' for x in values2]

fig = sb.barplot(x='countryB', y= 'perc',data=p2,palette=clrs2,order= ['GB','FR','IT','ES','DE','BE','PT','NL'])
sb.despine(left=True)
fig.set(xlabel='Percentage purchase price compared to Germany', ylabel='Buyer country')
# Out:
# [Text(0,0.5,'Buyer country'),
#  Text(0.5,0,'Percentage purchase price compared to Germany')]

# %%
pricediff = df['price_tm']-df['price']
len(pricediff)
# Out:
# 767

# %%
sb.set_style("whitegrid")
sb.distplot(pricediff, kde=True,bins=35, rug=True,color='#30678D')
plt.xlabel('Difference between MV and TF')
sb.despine(left=True)
# Out:
# C:\Users\letym\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
len(pricediff[pricediff<1])
# Out:
# 643

# %%
len(pricediff[pricediff>-1])
# Out:
# 678

# %%
(767-751) + (767-748)
# Out:
# 35

# %%
(767-643) + (767-678)
# Out:
# 213
